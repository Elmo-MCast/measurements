# %%
run_name = 'current'

# %%
import os
import glob
from functools import reduce

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# display plots in the notebook
# %matplotlib inline

# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/conda/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# ## Client side analysis

# %%
# read in the data
data_dict = dict()

for d in [f for f in glob.glob("./results/" + run_name + "/httperf_*") if not 'percentiles' in f]:
    data_list = []
    for i in glob.glob(d + "/httperf_client_*.csv"):
        data_list.append(pd.read_csv(i, header=0, na_filter=False))

    data_frame = pd.DataFrame()
    for i in ['Rate', 'Request rate', 'Number of requests',
              'Response status 1xx', 'Response status 2xx', 'Response status 3xx', 
              'Response status 4xx', 'Response status 5xx']:
        data_frame[i] = reduce(lambda x, y: x + y, [data_list[j][i] for j in range(len(data_list))])
        
    data_frame['Response time'] = reduce(lambda x, y: x + y, [data_list[j]['Response time'] 
                                                              for j in range(len(data_list))]) / len(data_list)
    data_dict[os.path.basename(d)] = data_frame

# %% [markdown]
# ### 1. Request rate analysis

# %%
plot_request_unbalance = pd.DataFrame()
plot_request_balance = pd.DataFrame()

plot_request_unbalance['Rate'] = data_dict[list(data_dict.keys())[0]]['Rate']
plot_request_balance['Rate'] = data_dict[list(data_dict.keys())[0]]['Rate']
    
for d in data_dict:
    if '_unbalance_' in d:
        plot_request_unbalance['Request rate - ' + d] = data_dict[d]['Request rate']
    if '_balance_' in d:
        plot_request_balance['Request rate - ' + d] = data_dict[d]['Request rate']

# %%
plot_request_unbalance.plot('Rate')

# %%
plot_request_balance.plot('Rate')

# %%
plot_request_unbalance.describe()
# Out:
#                Rate  Request rate - httperf_unbalance_wlc_to1  \
# count     50.000000                                 50.000000
# mean    8160.000000                               3518.214000
# std     4664.761516                               1144.849693
# min      320.000000                                320.000000
# 25%     4240.000000                               3136.825000
# 50%     8160.000000                               3737.100000
# 75%    12080.000000                               4323.500000
# max    16000.000000                               5056.800000
#
#        Request rate - httperf_unbalance_wrr_to1  \
# count                                 50.000000
# mean                                3375.414000
# std                                 1118.606565
# min                                  320.000000
# 25%                                 3040.025000
# 50%                                 3473.500000
# 75%                                 4310.450000
# max                                 4853.400000
#
#        Request rate - httperf_unbalance_wrr_to1_fdb  \
# count                                     50.000000
# mean                                    3577.782000
# std                                     1239.070605
# min                                      319.800000
# 25%                                     3113.825000
# 50%                                     3650.450000
# 75%                                     4670.675000
# max                                     5263.600000
#
#        Request rate - httperf_unbalance_wlc_to1_fdb
# count                                     50.000000
# mean                                    3613.050000
# std                                     1212.235215
# min                                      320.000000
# 25%                                     3066.150000
# 50%                                     3913.950000
# 75%                                     4501.500000
# max                                     5738.800000

# %%
plot_request_balance.describe()
# Out:
#                Rate  Request rate - httperf_balance_wrr_to1_fdb  \
# count     50.000000                                   50.000000
# mean    8160.000000                                 3342.318000
# std     4664.761516                                 1088.639806
# min      320.000000                                  320.000000
# 25%     4240.000000                                 2896.725000
# 50%     8160.000000                                 3567.150000
# 75%    12080.000000                                 3787.825000
# max    16000.000000                                 5658.300000
#
#        Request rate - httperf_balance_wrr_to1  \
# count                               50.000000
# mean                              3295.716000
# std                               1075.445836
# min                                320.000000
# 25%                               2873.400000
# 50%                               3469.500000
# 75%                               3859.075000
# max                               5378.500000
#
#        Request rate - httperf_balance_wlc_to1_fdb  \
# count                                   50.000000
# mean                                  3377.050000
# std                                   1130.738578
# min                                    320.000000
# 25%                                   2796.625000
# 50%                                   3613.150000
# 75%                                   3951.775000
# max                                   5698.000000
#
#        Request rate - httperf_balance_wlc_to1
# count                               50.000000
# mean                              3394.754000
# std                               1089.993505
# min                                320.000000
# 25%                               2976.675000
# 50%                               3605.200000
# 75%                               3931.375000
# max                               5430.900000

# %% [markdown]
# ### 2. Response time analysis

# %%
plot_response_unbalance = pd.DataFrame()
plot_response_balance = pd.DataFrame()

plot_response_unbalance['Rate'] = data_dict[list(data_dict.keys())[0]]['Rate']
plot_response_balance['Rate'] = data_dict[list(data_dict.keys())[0]]['Rate']
    
for d in data_dict:
    if '_unbalance_' in d:
        plot_response_unbalance['Response time - ' + d] = data_dict[d]['Response time']
    if '_balance_' in d:
        plot_response_balance['Response time - ' + d] = data_dict[d]['Response time']

# %%
plot_response_unbalance.plot('Rate')

# %%
plot_response_balance.plot('Rate')

# %%
plot_response_unbalance.describe()
# Out:
#                Rate  Response time - httperf_unbalance_wlc_to1  \
# count     50.000000                                  50.000000
# mean    8160.000000                                 167.927375
# std     4664.761516                                 137.856134
# min      320.000000                                   3.212500
# 25%     4240.000000                                  26.898438
# 50%     8160.000000                                 146.212500
# 75%    12080.000000                                 298.832813
# max    16000.000000                                 395.718750
#
#        Response time - httperf_unbalance_wrr_to1  \
# count                                  50.000000
# mean                                  156.866000
# std                                   130.801810
# min                                     3.600000
# 25%                                    30.953125
# 50%                                   153.528125
# 75%                                   273.975000
# max                                   374.831250
#
#        Response time - httperf_unbalance_wrr_to1_fdb  \
# count                                      50.000000
# mean                                      159.221625
# std                                       137.692285
# min                                         3.112500
# 25%                                        21.656250
# 50%                                       145.093750
# 75%                                       289.720312
# max                                       370.350000
#
#        Response time - httperf_unbalance_wlc_to1_fdb
# count                                      50.000000
# mean                                      163.717000
# std                                       127.771199
# min                                         9.393750
# 25%                                        25.173437
# 50%                                       178.331250
# 75%                                       283.610937
# max                                       370.818750

# %%
plot_response_balance.describe()
# Out:
#                Rate  Response time - httperf_balance_wrr_to1_fdb  \
# count     50.000000                                    50.000000
# mean    8160.000000                                   178.858875
# std     4664.761516                                   139.148703
# min      320.000000                                     1.206250
# 25%     4240.000000                                     7.440625
# 50%     8160.000000                                   237.231250
# 75%    12080.000000                                   286.506250
# max    16000.000000                                   381.200000
#
#        Response time - httperf_balance_wrr_to1  \
# count                                50.000000
# mean                                186.213250
# std                                 147.732167
# min                                   1.200000
# 25%                                   7.804688
# 50%                                 235.337500
# 75%                                 294.385938
# max                                 450.450000
#
#        Response time - httperf_balance_wlc_to1_fdb  \
# count                                    50.000000
# mean                                    170.052125
# std                                     137.520184
# min                                       1.175000
# 25%                                       7.754687
# 50%                                     233.371875
# 75%                                     276.571875
# max                                     395.381250
#
#        Response time - httperf_balance_wlc_to1
# count                                50.000000
# mean                                175.613750
# std                                 139.907279
# min                                   1.225000
# 25%                                   7.651563
# 50%                                 232.681250
# 75%                                 280.821875
# max                                 386.168750

# %% [markdown]
# ### 3. Success rate analysis

# %%
plot_success_unbalance = pd.DataFrame()
plot_success_balance = pd.DataFrame()

plot_success_unbalance['Rate'] = data_dict[list(data_dict.keys())[0]]['Rate']
plot_success_balance['Rate'] = data_dict[list(data_dict.keys())[0]]['Rate']
    
for d in data_dict:
    if '_unbalance_' in d:
        plot_success_unbalance['Success rate - ' + d] = (data_dict[d]['Response status 2xx'] + 
                                                         data_dict[d]['Response status 3xx']) / data_dict[d]['Number of requests'] * 100.0
    if '_balance_' in d:
        plot_success_balance['Success rate - ' + d] = (data_dict[d]['Response status 2xx'] + 
                                                       data_dict[d]['Response status 3xx']) / data_dict[d]['Number of requests'] * 100.0

# %%
plot_success_unbalance.plot('Rate')

# %%
plot_success_balance.plot('Rate')

# %%
plot_success_unbalance.describe()
# Out:
#                Rate  Success rate - httperf_unbalance_wlc_to1  \
# count     50.000000                                 50.000000
# mean    8160.000000                                 87.274208
# std     4664.761516                                 12.427657
# min      320.000000                                 59.380653
# 25%     4240.000000                                 78.343270
# 50%     8160.000000                                 93.424462
# 75%    12080.000000                                 97.308792
# max    16000.000000                                100.000000
#
#        Success rate - httperf_unbalance_wrr_to1  \
# count                                 50.000000
# mean                                  88.029359
# std                                   11.818414
# min                                   60.912362
# 25%                                   82.258964
# 50%                                   93.210461
# 75%                                   96.818341
# max                                  100.000000
#
#        Success rate - httperf_unbalance_wrr_to1_fdb  \
# count                                     50.000000
# mean                                      87.661245
# std                                       13.212992
# min                                       62.583115
# 25%                                       77.546331
# 50%                                       95.334814
# 75%                                       97.603481
# max                                      100.000000
#
#        Success rate - httperf_unbalance_wlc_to1_fdb
# count                                     50.000000
# mean                                      88.676641
# std                                       11.349947
# min                                       59.728011
# 25%                                       81.665944
# 50%                                       92.197078
# 75%                                       97.561505
# max                                       99.937498

# %%
plot_success_balance.describe()
# Out:
#                Rate  Success rate - httperf_balance_wrr_to1_fdb  \
# count     50.000000                                   50.000000
# mean    8160.000000                                   87.498166
# std     4664.761516                                   12.653779
# min      320.000000                                   59.794872
# 25%     4240.000000                                   79.891117
# 50%     8160.000000                                   89.342376
# 75%    12080.000000                                  100.000000
# max    16000.000000                                  100.000000
#
#        Success rate - httperf_balance_wrr_to1  \
# count                               50.000000
# mean                                85.905768
# std                                 14.750354
# min                                 53.953551
# 25%                                 76.900874
# 50%                                 89.238626
# 75%                                100.000000
# max                                100.000000
#
#        Success rate - httperf_balance_wlc_to1_fdb  \
# count                                   50.000000
# mean                                    87.740770
# std                                     12.896921
# min                                     59.829666
# 25%                                     80.639781
# 50%                                     88.702463
# 75%                                    100.000000
# max                                    100.000000
#
#        Success rate - httperf_balance_wlc_to1
# count                               50.000000
# mean                                87.280239
# std                                 13.303998
# min                                 58.705842
# 25%                                 79.036157
# 50%                                 89.660168
# 75%                                100.000000
# max                                100.000000

# %% [markdown]
# ## Server side analysis

# %%
# read in the data
stats_dict = dict()

for d in [f for f in glob.glob("./results/" + run_name + "/httperf_*") if not 'percentiles' in f]:
    stats_frame = pd.read_csv(d + "/httperf_server_stats.csv", header=0, na_filter=False)
    for i in ['Connections', 'Packets', 'Bytes (K)']:
        stats_frame[i + ' Ratio (%)'] = stats_frame[i] / sum(stats_frame[i]) * 100
    
    stats_dict[os.path.basename(d)] = stats_frame

# %% [markdown]
# ### 1. Connections ratio (%)

# %%
plot_connections_unbalance = pd.DataFrame()
plot_connections_balance = pd.DataFrame()

plot_connections_unbalance['Server'] = stats_dict[list(stats_dict.keys())[0]]['Server']
plot_connections_balance['Server'] = stats_dict[list(stats_dict.keys())[0]]['Server']
    
for d in stats_dict:
    if '_unbalance_' in d:
        plot_connections_unbalance['Connections Ratio (%) - ' + d] = stats_dict[d]['Connections Ratio (%)']
    if '_balance_' in d:
        plot_connections_balance['Connections Ratio (%) - ' + d] = stats_dict[d]['Connections Ratio (%)']

# %%
plot_connections_unbalance.plot('Server', kind='bar')

# %%
plot_connections_balance.plot('Server', kind='bar')

# %% [markdown]
# ### 2. Packets ratio (%)

# %%
plot_packets_unbalance = pd.DataFrame()
plot_packets_balance = pd.DataFrame()

plot_packets_unbalance['Server'] = stats_dict[list(stats_dict.keys())[0]]['Server']
plot_packets_balance['Server'] = stats_dict[list(stats_dict.keys())[0]]['Server']
    
for d in stats_dict:
    if '_unbalance_' in d:
        plot_packets_unbalance['Packets Ratio (%) - ' + d] = stats_dict[d]['Packets Ratio (%)']
    if '_balance_' in d:
        plot_packets_balance['Packets Ratio (%) - ' + d] = stats_dict[d]['Packets Ratio (%)']

# %%
plot_packets_unbalance.plot('Server', kind='bar')

# %%
plot_packets_balance.plot('Server', kind='bar')

# %% [markdown]
# ### 3. Bytes ratio (%)

# %%
plot_bytes_unbalance = pd.DataFrame()
plot_bytes_balance = pd.DataFrame()

plot_bytes_unbalance['Server'] = stats_dict[list(stats_dict.keys())[0]]['Server']
plot_bytes_balance['Server'] = stats_dict[list(stats_dict.keys())[0]]['Server']
    
for d in stats_dict:
    if '_unbalance_' in d:
        plot_bytes_unbalance['Bytes (K) Ratio (%) - ' + d] = stats_dict[d]['Bytes (K) Ratio (%)']
    if '_balance_' in d:
        plot_bytes_balance['Bytes (K) Ratio (%) - ' + d] = stats_dict[d]['Bytes (K) Ratio (%)']

# %%
plot_bytes_unbalance.plot('Server', kind='bar')

# %%
plot_bytes_balance.plot('Server', kind='bar')
