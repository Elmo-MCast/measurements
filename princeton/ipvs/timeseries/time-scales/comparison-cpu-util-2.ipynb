# %%
import os
import glob
from functools import reduce

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# display plots in the notebook
# %matplotlib inline

# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
results_dir = "../../results/"
base_dir = "timeseries/time-scales/"

# %% [markdown]
# ## CPU Utilization

# %%
cpu_util = pd.read_csv(results_dir + base_dir + "cpu-util-feedback-2.csv", header=0, na_filter=False)

# %%
ax = cpu_util.plot('feedback-interval', kind='bar', figsize=(7,6))
ax.set_ylabel('CPU Util (%)')
fig = ax.get_figure()
fig.savefig('time-scales-plots-for-cpu-util-2.pdf')
