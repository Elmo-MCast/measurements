# %%
import os
import glob
from functools import reduce

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# display plots in the notebook
# %matplotlib inline

# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# ## Response rate

# %%
wlc_1r_rr_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/three-backends/500ms/10mins-run/wlc/1st-seed-run/response_rate.csv', header=0, na_filter=False)
wlc_2r_rr_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/three-backends/500ms/10mins-run/wlc/2nd-seed-run/response_rate.csv', header=0, na_filter=False)
# wlc_3r_rr_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/two-backends/500ms/10mins-run/wlc/3rd-seed-run/response_rate.csv', header=0, na_filter=False)
fdb_wlc_1r_rr_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/three-backends/500ms/10mins-run/feedback-wlc/1st-seed-run/response_rate.csv', header=0, na_filter=False)
fdb_wlc_2r_rr_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/three-backends/500ms/10mins-run/feedback-wlc/2nd-seed-run/response_rate.csv', header=0, na_filter=False)
# fdb_wlc_3r_rr_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/two-backends/500ms/10mins-run/feedback-wlc/3rd-seed-run/response_rate.csv', header=0, na_filter=False)

# %%
rr_plot = pd.DataFrame()

rr_plot['percentiles'] = ['Request rate', 'Response rate 50%', 'Response rate 66%', 'Response rate 75%',
                          'Response rate 80%', 'Response rate 90%', 'Response rate 95%', 'Response rate 98%',
                          'Response rate 99%', 'Response rate 100%'] 

wlc_1r_rr_list = []
wlc_2r_rr_list = []
# wlc_3r_rr_list = []
fdb_wlc_1r_rr_list = []
fdb_wlc_2r_rr_list = []
# fdb_wlc_3r_rr_list = []
for i in ['Request rate', 'Response rate 50%', 'Response rate 66%', 'Response rate 75%',
          'Response rate 80%', 'Response rate 90%', 'Response rate 95%', 'Response rate 98%',
          'Response rate 99%', 'Response rate 100%']:
    wlc_1r_rr_list.append(wlc_1r_rr_data[i][0])
    wlc_2r_rr_list.append(wlc_2r_rr_data[i][0])
#     wlc_3r_rr_list.append(wlc_3r_rr_data[i][0])    
    fdb_wlc_1r_rr_list.append(fdb_wlc_1r_rr_data[i][0])
    fdb_wlc_2r_rr_list.append(fdb_wlc_2r_rr_data[i][0])
#     fdb_wlc_3r_rr_list.append(fdb_wlc_3r_rr_data[i][0])    
    
rr_plot['wlc-1r'] = wlc_1r_rr_list
rr_plot['wlc-2r'] = wlc_2r_rr_list
# rr_plot['wlc-3r'] = wlc_3r_rr_list
rr_plot['feedback-wlc-1r'] = fdb_wlc_1r_rr_list
rr_plot['feedback-wlc-2r'] = fdb_wlc_2r_rr_list
# rr_plot['feedback-wlc-3r'] = fdb_wlc_3r_rr_list

# %%
rr_plot.plot('percentiles', kind='bar')

# %% [markdown]
# ## Response time

# %%
wlc_1r_rt_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/three-backends/500ms/10mins-run/wlc/1st-seed-run/response_time.csv', header=0, na_filter=False)
wlc_2r_rt_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/three-backends/500ms/10mins-run/wlc/2nd-seed-run/response_time.csv', header=0, na_filter=False)
# wlc_3r_rt_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/two-backends/500ms/10mins-run/wlc/3rd-seed-run/response_time.csv', header=0, na_filter=False)
fdb_wlc_1r_rt_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/three-backends/500ms/10mins-run/feedback-wlc/1st-seed-run/response_time.csv', header=0, na_filter=False)
fdb_wlc_2r_rt_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/three-backends/500ms/10mins-run/feedback-wlc/2nd-seed-run/response_time.csv', header=0, na_filter=False)
# fdb_wlc_3r_rt_data = pd.read_csv('../../../../../../results/timeseries/timeout-1sec/time-varying/two-backends/500ms/10mins-run/feedback-wlc/3rd-seed-run/response_time.csv', header=0, na_filter=False)

# %%
rt_plot = pd.DataFrame()

rt_plot['percentiles'] = ['Response time', 'Response time 50%', 'Response time 66%', 'Response time 75%',
                          'Response time 80%', 'Response time 90%', 'Response time 95%', 'Response time 98%',
                          'Response time 99%', 'Response time 100%'] 

wlc_1r_rt_list = []
wlc_2r_rt_list = []
# wlc_3r_rt_list = []
fdb_wlc_1r_rt_list = []
fdb_wlc_2r_rt_list = []
# fdb_wlc_3r_rt_list = []
for i in ['Response time', 'Response time 50%', 'Response time 66%', 'Response time 75%',
          'Response time 80%', 'Response time 90%', 'Response time 95%', 'Response time 98%',
          'Response time 99%', 'Response time 100%']:
    wlc_1r_rt_list.append(wlc_1r_rt_data[i][0])
    wlc_2r_rt_list.append(wlc_2r_rt_data[i][0])
#     wlc_3r_rt_list.append(wlc_3r_rt_data[i][0])    
    fdb_wlc_1r_rt_list.append(fdb_wlc_1r_rt_data[i][0])
    fdb_wlc_2r_rt_list.append(fdb_wlc_2r_rt_data[i][0])
#     fdb_wlc_3r_rt_list.append(fdb_wlc_3r_rt_data[i][0])
    
rt_plot['wlc-1r'] = wlc_1r_rt_list
rt_plot['wlc-2r'] = wlc_2r_rt_list
# rt_plot['wlc-3r'] = wlc_3r_rt_list
rt_plot['feedback-wlc-1r'] = fdb_wlc_1r_rt_list
rt_plot['feedback-wlc-2r'] = fdb_wlc_2r_rt_list
# rt_plot['feedback-wlc-3r'] = fdb_wlc_3r_rt_list

# %% [markdown]
# ### Percentiles ...
#
# 10sec fluctuation, 10ms feedback, 0.5 alpha, 0.001 state feedback, 0.001 stat collection.

# %%
wlc_err = pd.DataFrame()
fdb_wlc_err = pd.DataFrame()
for i in range(len(
    ['Response time', 'Response time 50%', 'Response time 66%', 'Response time 75%',
          'Response time 80%', 'Response time 90%', 'Response time 95%', 'Response time 98%',
          'Response time 99%', 'Response time 100%'])):
    wlc_err[rt_plot['percentiles'][i]] = [rt_plot['wlc-1r'][i],
                                          rt_plot['wlc-2r'][i]]
#                                           rt_plot['wlc-3r'][i]]
    fdb_wlc_err[rt_plot['percentiles'][i]] = [rt_plot['feedback-wlc-1r'][i],
                                              rt_plot['feedback-wlc-2r'][i]]
#                                               rt_plot['feedback-wlc-3r'][i]]

means = pd.DataFrame()
means['percentiles'] = rt_plot['percentiles']
errs = pd.DataFrame()
errs['percentiles'] = rt_plot['percentiles']
means['wlc'] = list(wlc_err.mean())
errs['wlc'] = list(wlc_err.std())
means['feedback-wlc'] = list(fdb_wlc_err.mean())
errs['feedback-wlc'] = list(fdb_wlc_err.std())

means.plot(kind='bar', yerr=errs)

# %%
means.describe()
# Out:
#               wlc  feedback-wlc
# count   10.000000     10.000000
# mean   164.839375    173.566875
# std    169.370798    183.040842
# min     15.187500     20.250000
# 25%     28.234375     35.703125
# 50%     90.603125     79.365625
# 75%    287.203125    292.296875
# max    495.187500    556.750000

# %% [markdown]
# ### Below ...
# 10sec fluctuation, 10ms feedback, 0.5 alpha, 0.001 state feedback, 0.001 stat collection.

# %%
rt_plot[['percentiles', 'wlc-1r', 'feedback-wlc-1r']].plot('percentiles', kind='bar')

# %%
rt_plot[['percentiles', 'wlc-2r', 'feedback-wlc-2r']].plot('percentiles', kind='bar')

# %%
# rt_plot[['percentiles', 'wlc-3r', 'feedback-wlc-3r']].plot('percentiles', kind='bar')

# %%
rt_plot.plot('percentiles', kind='bar')
