# %%
import os
import glob
from functools import reduce

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# display plots in the notebook
# %matplotlib inline

# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# ## Response rate

# %%
# wrr_rr_data = pd.read_csv('../../../../../results/results/timeseries/timeout-1sec/wrr/wrr_response_rate.csv', header=0, na_filter=False)
# wlc_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc/wlc_response_rate.csv', header=0, na_filter=False)
# fdb_wrr_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wrr/feedback_wrr_response_rate.csv', header=0, na_filter=False)
# fdb_wlc_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc/feedback_wlc_response_rate.csv', header=0, na_filter=False)
# wlc_alt_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt/wlc_alt_response_rate.csv', header=0, na_filter=False)
# fdb_wlc_alt_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt/feedback_wlc_alt_response_rate.csv', header=0, na_filter=False)
# wlc_alt_2s_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt-2sec-fb/wlc_alt_response_rate.csv', header=0, na_filter=False)
# fdb_wlc_alt_2s_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt-2sec-fb/feedback_wlc_alt_response_rate.csv', header=0, na_filter=False)
# wlc_alt_2_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt-2/wlc_alt_2_response_rate.csv', header=0, na_filter=False)
# fdb_wlc_alt_2_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt-2/feedback_wlc_alt_2_response_rate.csv', header=0, na_filter=False)
# wlc_alt_3_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt-3/wlc_alt_3_response_rate.csv', header=0, na_filter=False)
# fdb_wlc_alt_3_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt-3/feedback_wlc_alt_3_response_rate.csv', header=0, na_filter=False)
wlc_alt_4_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt-4/wlc_alt_4_response_rate.csv', header=0, na_filter=False)
fdb_wlc_alt_4_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt-4/feedback_wlc_alt_4_response_rate.csv', header=0, na_filter=False)
wlc_alt_5_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt-5/wlc_alt_5_response_rate.csv', header=0, na_filter=False)
fdb_wlc_alt_5_rr_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt-5/feedback_wlc_alt_5_response_rate.csv', header=0, na_filter=False)

# %%
rr_plot = pd.DataFrame()

rr_plot['percentiles'] = ['Request rate', 'Response rate 50%', 'Response rate 66%', 'Response rate 75%',
                          'Response rate 80%', 'Response rate 90%', 'Response rate 95%', 'Response rate 98%',
                          'Response rate 99%', 'Response rate 100%'] 

# wrr_rr_list = []
# wlc_rr_list = []
# fdb_wrr_rr_list = []
# fdb_wlc_rr_list = []
# wlc_alt_rr_list = []
# fdb_wlc_alt_rr_list = []
# wlc_alt_2s_rr_list = []
# fdb_wlc_alt_2s_rr_list = []
# wlc_alt_2_rr_list = []
# fdb_wlc_alt_2_rr_list = []
# wlc_alt_3_rr_list = []
# fdb_wlc_alt_3_rr_list = []
wlc_alt_4_rr_list = []
fdb_wlc_alt_4_rr_list = []
wlc_alt_5_rr_list = []
fdb_wlc_alt_5_rr_list = []
for i in ['Request rate', 'Response rate 50%', 'Response rate 66%', 'Response rate 75%',
          'Response rate 80%', 'Response rate 90%', 'Response rate 95%', 'Response rate 98%',
          'Response rate 99%', 'Response rate 100%']:
#     wrr_rr_list.append(wrr_rr_data[i][0])
#     wlc_rr_list.append(wlc_rr_data[i][0])
#     fdb_wrr_rr_list.append(fdb_wrr_rr_data[i][0])
#     fdb_wlc_rr_list.append(fdb_wlc_rr_data[i][0])
#     wlc_alt_rr_list.append(wlc_alt_rr_data[i][0])
#     fdb_wlc_alt_rr_list.append(fdb_wlc_alt_rr_data[i][0])
#     wlc_alt_2s_rr_list.append(wlc_alt_2s_rr_data[i][0])
#     fdb_wlc_alt_2s_rr_list.append(fdb_wlc_alt_2s_rr_data[i][0])
#     wlc_alt_2_rr_list.append(wlc_alt_2_rr_data[i][0])
#     fdb_wlc_alt_2_rr_list.append(fdb_wlc_alt_2_rr_data[i][0])
#     wlc_alt_3_rr_list.append(wlc_alt_3_rr_data[i][0])
#     fdb_wlc_alt_3_rr_list.append(fdb_wlc_alt_3_rr_data[i][0])
    wlc_alt_4_rr_list.append(wlc_alt_4_rr_data[i][0])
    fdb_wlc_alt_4_rr_list.append(fdb_wlc_alt_4_rr_data[i][0])
    wlc_alt_5_rr_list.append(wlc_alt_5_rr_data[i][0])
    fdb_wlc_alt_5_rr_list.append(fdb_wlc_alt_5_rr_data[i][0])

    
# rr_plot['wrr'] = wrr_rr_list
# rr_plot['wlc'] = wlc_rr_list
# rr_plot['feedback-wrr'] = fdb_wrr_rr_list
# rr_plot['feedback-wlc'] = fdb_wlc_rr_list
# rr_plot['wlc-alt-2s'] = wlc_alt_2s_rr_list
# rr_plot['feedback-wlc-alt-2s'] = fdb_wlc_alt_2s_rr_list
# rr_plot['wlc-alt'] = wlc_alt_rr_list
# rr_plot['feedback-wlc-alt'] = fdb_wlc_alt_rr_list
# rr_plot['wlc-alt-2'] = wlc_alt_2_rr_list
# rr_plot['feedback-wlc-alt-2'] = fdb_wlc_alt_2_rr_list
# rr_plot['wlc-alt-3'] = wlc_alt_3_rr_list
# rr_plot['feedback-wlc-alt-3'] = fdb_wlc_alt_3_rr_list
rr_plot['wlc-alt-4'] = wlc_alt_4_rr_list
rr_plot['feedback-wlc-alt-4'] = fdb_wlc_alt_4_rr_list
rr_plot['wlc-alt-5'] = wlc_alt_5_rr_list
rr_plot['feedback-wlc-alt-5'] = fdb_wlc_alt_5_rr_list

# %%
rr_plot.plot('percentiles', kind='bar')

# %% [markdown]
# ## Response time

# %%
# wrr_rt_data = pd.read_csv('../../results/timeseries/timeout-1sec/wrr/wrr_response_time.csv', header=0, na_filter=False)
# wlc_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc/wlc_response_time.csv', header=0, na_filter=False)
# fdb_wrr_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wrr/feedback_wrr_response_time.csv', header=0, na_filter=False)
# fdb_wlc_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc/feedback_wlc_response_time.csv', header=0, na_filter=False)
# wlc_alt_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt/wlc_alt_response_time.csv', header=0, na_filter=False)
# fdb_wlc_alt_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt/feedback_wlc_alt_response_time.csv', header=0, na_filter=False)
# wlc_alt_2s_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt-2sec-fb/wlc_alt_response_time.csv', header=0, na_filter=False)
# fdb_wlc_alt_2s_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt-2sec-fb/feedback_wlc_alt_response_time.csv', header=0, na_filter=False)
# wlc_alt_2_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt-2/wlc_alt_2_response_time.csv', header=0, na_filter=False)
# fdb_wlc_alt_2_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt-2/feedback_wlc_alt_2_response_time.csv', header=0, na_filter=False)
# wlc_alt_3_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt-3/wlc_alt_3_response_time.csv', header=0, na_filter=False)
# fdb_wlc_alt_3_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt-3/feedback_wlc_alt_3_response_time.csv', header=0, na_filter=False)
wlc_alt_4_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt-4/wlc_alt_4_response_time.csv', header=0, na_filter=False)
fdb_wlc_alt_4_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt-4/feedback_wlc_alt_4_response_time.csv', header=0, na_filter=False)
wlc_alt_5_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/wlc-alt-5/wlc_alt_5_response_time.csv', header=0, na_filter=False)
fdb_wlc_alt_5_rt_data = pd.read_csv('../../../../../results/timeseries/timeout-1sec/time-varying/all-backends/10s/feedback-wlc-alt-5/feedback_wlc_alt_5_response_time.csv', header=0, na_filter=False)

# %%
rt_plot = pd.DataFrame()

rt_plot['percentiles'] = ['Response time', 'Response time 50%', 'Response time 66%', 'Response time 75%',
                          'Response time 80%', 'Response time 90%', 'Response time 95%', 'Response time 98%',
                          'Response time 99%', 'Response time 100%'] 

# wrr_rt_list = []
# wlc_rt_list = []
# fdb_wrr_rt_list = []
# fdb_wlc_rt_list = []
# wlc_alt_rt_list = []
# fdb_wlc_alt_rt_list = []
# wlc_alt_2s_rt_list = []
# fdb_wlc_alt_2s_rt_list = []
# wlc_alt_2_rt_list = []
# fdb_wlc_alt_2_rt_list = []
# wlc_alt_3_rt_list = []
# fdb_wlc_alt_3_rt_list = []
wlc_alt_4_rt_list = []
fdb_wlc_alt_4_rt_list = []
wlc_alt_5_rt_list = []
fdb_wlc_alt_5_rt_list = []
for i in ['Response time', 'Response time 50%', 'Response time 66%', 'Response time 75%',
          'Response time 80%', 'Response time 90%', 'Response time 95%', 'Response time 98%',
          'Response time 99%', 'Response time 100%']:
#     wrr_rt_list.append(wrr_rt_data[i][0])
#     wlc_rt_list.append(wlc_rt_data[i][0])
#     fdb_wrr_rt_list.append(fdb_wrr_rt_data[i][0])
#     fdb_wlc_rt_list.append(fdb_wlc_rt_data[i][0])
#     wlc_alt_rt_list.append(wlc_alt_rt_data[i][0])
#     fdb_wlc_alt_rt_list.append(fdb_wlc_alt_rt_data[i][0])
#     wlc_alt_2s_rt_list.append(wlc_alt_2s_rt_data[i][0])
#     fdb_wlc_alt_2s_rt_list.append(fdb_wlc_alt_2s_rt_data[i][0])
#     wlc_alt_2_rt_list.append(wlc_alt_2_rt_data[i][0])
#     fdb_wlc_alt_2_rt_list.append(fdb_wlc_alt_2_rt_data[i][0])
#     wlc_alt_3_rt_list.append(wlc_alt_3_rt_data[i][0])
#     fdb_wlc_alt_3_rt_list.append(fdb_wlc_alt_3_rt_data[i][0])
    wlc_alt_4_rt_list.append(wlc_alt_4_rt_data[i][0])
    fdb_wlc_alt_4_rt_list.append(fdb_wlc_alt_4_rt_data[i][0])
    wlc_alt_5_rt_list.append(wlc_alt_5_rt_data[i][0])
    fdb_wlc_alt_5_rt_list.append(fdb_wlc_alt_5_rt_data[i][0])
    
# rt_plot['wlc'] = wlc_rt_list
# rt_plot['feedback-wrr'] = fdb_wrr_rt_list
# rt_plot['feedback-wlc'] = fdb_wlc_rt_list
# rt_plot['wlc-alt-2s'] = wlc_alt_2s_rt_list
# rt_plot['feedback-wlc-alt-2s'] = fdb_wlc_alt_2s_rt_list
# rt_plot['wlc-alt'] = wlc_alt_rt_list
# rt_plot['feedback-wlc-alt'] = fdb_wlc_alt_rt_list
# rt_plot['wlc-alt-2'] = wlc_alt_2_rt_list
# rt_plot['feedback-wlc-alt-2'] = fdb_wlc_alt_2_rt_list
# rt_plot['wlc-alt-3'] = wlc_alt_3_rt_list
# rt_plot['feedback-wlc-alt-3'] = fdb_wlc_alt_3_rt_list
rt_plot['wlc-alt-4'] = wlc_alt_4_rt_list
rt_plot['feedback-wlc-alt-4'] = fdb_wlc_alt_4_rt_list
rt_plot['wlc-alt-5'] = wlc_alt_5_rt_list
rt_plot['feedback-wlc-alt-5'] = fdb_wlc_alt_5_rt_list

# %% [markdown]
# ### Below ...
# 10sec fluctuation, 10ms feedback, 0.1 alpha, 0.01 state feedback, 0.01 stat collection.

# %%
# rt_plot[['percentiles', 'wlc-alt', 'feedback-wlc-alt']].plot('percentiles', kind='bar')

# %%
# rt_plot[['percentiles', 'wlc-alt-2', 'feedback-wlc-alt-2']].plot('percentiles', kind='bar')

# %%
# rt_plot[['percentiles', 'wlc-alt-3', 'feedback-wlc-alt-3']].plot('percentiles', kind='bar')

# %% [markdown]
# ### Below ...
# 10sec fluctuation, 10ms feedback, 0.5 alpha, 0.001 state feedback, 0.001 stat collection.

# %%
rt_plot[['percentiles', 'wlc-alt-4', 'feedback-wlc-alt-4']].plot('percentiles', kind='bar')

# %%
rt_plot[['percentiles', 'wlc-alt-5', 'feedback-wlc-alt-5']].plot('percentiles', kind='bar')

# %%
rt_plot[['percentiles', 'wlc-alt-4', 'feedback-wlc-alt-4', 'wlc-alt-5', 'feedback-wlc-alt-5']].plot('percentiles', kind='bar')
