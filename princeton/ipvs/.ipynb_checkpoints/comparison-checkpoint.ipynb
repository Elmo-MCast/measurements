# %%
import os
import glob
from functools import reduce

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# display plots in the notebook
# %matplotlib inline

# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# ## Response rate

# %%
wlc_rr_data = pd.read_csv('./results/wlc/wlc_response_rate.csv', header=0, na_filter=False)
fdb_wrr_rr_data = pd.read_csv('./results/feedback-wrr/feedback_wrr_response_rate.csv', header=0, na_filter=False)
fdb_wlc_rr_data = pd.read_csv('./results/feedback-wlc/feedback_wlc_response_rate.csv', header=0, na_filter=False)

# %%
rr_plot = pd.DataFrame()

rr_plot['percentiles'] = ['Request rate', 'Response rate 50%', 'Response rate 66%', 'Response rate 75%',
                          'Response rate 80%', 'Response rate 90%', 'Response rate 95%', 'Response rate 98%',
                          'Response rate 99%', 'Response rate 100%'] 

wlc_rr_list = []
fdb_wrr_rr_list = []
fdb_wlc_rr_list = []
for i in ['Request rate', 'Response rate 50%', 'Response rate 66%', 'Response rate 75%',
          'Response rate 80%', 'Response rate 90%', 'Response rate 95%', 'Response rate 98%',
          'Response rate 99%', 'Response rate 100%']:
    wlc_rr_list.append(wlc_rr_data[i][0])
    fdb_wrr_rr_list.append(fdb_wrr_rr_data[i][0])
    fdb_wlc_rr_list.append(fdb_wlc_rr_data[i][0])
    
rr_plot['wlc'] = wlc_rr_list
rr_plot['feedback-wrr'] = fdb_wrr_rr_list
rr_plot['feedback-wlc'] = fdb_wlc_rr_list

# %%
rr_plot.plot('percentiles', kind='bar')

# %% [markdown]
# ## Response time

# %%
wlc_rt_data = pd.read_csv('./results/wlc/wlc_response_time.csv', header=0, na_filter=False)
fdb_wrr_rt_data = pd.read_csv('./results/feedback-wrr/feedback_wrr_response_time.csv', header=0, na_filter=False)
fdb_wlc_rt_data = pd.read_csv('./results/feedback-wlc/feedback_wlc_response_time.csv', header=0, na_filter=False)

# %%
rt_plot = pd.DataFrame()

rt_plot['percentiles'] = ['Response time', 'Response time 50%', 'Response time 66%', 'Response time 75%',
                          'Response time 80%', 'Response time 90%', 'Response time 95%', 'Response time 98%',
                          'Response time 99%', 'Response time 100%'] 

wlc_rt_list = []
fdb_wrr_rt_list = []
fdb_wlc_rt_list = []
for i in ['Response time', 'Response time 50%', 'Response time 66%', 'Response time 75%',
          'Response time 80%', 'Response time 90%', 'Response time 95%', 'Response time 98%',
          'Response time 99%', 'Response time 100%']:
    wlc_rt_list.append(wlc_rt_data[i][0])
    fdb_wrr_rt_list.append(fdb_wrr_rt_data[i][0])
    fdb_wlc_rt_list.append(fdb_wlc_rt_data[i][0])
    
rt_plot['wlc'] = wlc_rt_list
rt_plot['feedback-wrr'] = fdb_wrr_rt_list
rt_plot['feedback-wlc'] = fdb_wlc_rt_list

# %%
rt_plot.plot('percentiles', kind='bar')

# %% [markdown]
# ## Server stats

# %%
wlc_stats_data = pd.read_csv("./results/" + "wlc" + "/httperf_server_stats.csv", header=0, na_filter=False)
fdb_wrr_stats_data = pd.read_csv("./results/" + "feedback-wrr" + "/httperf_server_stats.csv", header=0, na_filter=False)
fdb_wlc_stats_data = pd.read_csv("./results/" + "feedback-wlc" + "/httperf_server_stats.csv", header=0, na_filter=False)

# %%
ss_plot_data = pd.DataFrame()

ss_plot_data['Server'] = wlc_stats_data['Server']

ss_plot_data['Connections: wlc'] = wlc_stats_data['Connections']
ss_plot_data['Connections: feedback-wrr'] = fdb_wrr_stats_data['Connections']
ss_plot_data['Connections: feedback-wlc'] = fdb_wlc_stats_data['Connections']

ss_plot_data
# Out:
#               Server  Connections: wlc  Connections: feedback-wrr  \
# 0  11.11.11.112:8080              1234                       1120
# 1  11.11.11.113:8080              1235                       1203
# 2  11.11.11.114:8080              1235                       1474
# 3  11.11.11.115:8080               136                         43
#
#    Connections: feedback-wlc
# 0                       1221
# 1                       1279
# 2                       1313
# 3                         27

# %%
ss_plot_data.plot('Server', kind='bar')
